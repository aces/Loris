# %% [markdown]
# # LORIS API Tour 2/2

# %% [markdown]
# ## Setup

# %%
import getpass  # For input prompt not to show what is entered
import json     # Provide convinent functions to handle json objects 
import re       # For regular expression
import requests # To handle http requests

import warnings
warnings.simplefilter('ignore') # Because I am using unverified ssl certificates 

baseurl = 'https://test-loris-dev.loris.ca/api/v0.0.3' # Pick yours

def prettyPrint(string):
    print(json.dumps(string, indent=2, sort_keys=True))

# %% [markdown]
# ## Exercise 1. Login
#
# This is a POST request to the `/login` endpoint that requires 2 parameters: `username` and `password`
# The expected response is a json string that contains a token property.
#
# https://github.com/aces/Loris/blob/minor/docs/API/LorisRESTAPI.md#11-authentication

# %%
payload = {
    'username': input('username: '), 
    'password': getpass.getpass('password: ')
}

response = requests.post(
    url = baseurl + '/login',
    json = payload,
    verify = False
)

text = response.content.decode('ascii')

data = json.loads(text)

prettyPrint(data)
# Out:
# username: admin
# password: ········
# {
#   "token": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJodHRwczpcL1wvdGVzdC1sb3Jpcy1kZXYubG9yaXMuY2EiLCJhdWQiOiJodHRwczpcL1wvdGVzdC1sb3Jpcy1kZXYubG9yaXMuY2EiLCJpYXQiOjE1OTUyODY4MjksIm5iZiI6MTU5NTI4NjgyOSwiZXhwIjoxNTk1MzczMjI5LCJ1c2VyIjoiYWRtaW4ifQ.jm9XknnS8noxR85DheIYYSyhDpZ8nVNplV8Y920YWj4"
# }

# %% [markdown]
# *Store the token in a variable for later*

# %%
token = data['token']

# %% [markdown]
# # Exercice 2 - Projects
#
# The endpoints in this section are used to get information on all candidates, to get information on a specific candidate or to add a new candidate.
#
# https://github.com/aces/Loris/blob/master/modules/api/docs/LorisRESTAPI_v0.0.3.md#20-project-api

# %% [markdown]
# ## Exercise 2.1 Get all projects
#
# The endpoint `/projects` can be used to obtain information on all the projects contained the database.

# %%
# Find the project name and site name.
projects = json.loads(requests.get(
    url = baseurl + '/projects',
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
).content.decode('ascii'))

prettyPrint(projects)
# Out:
# {
#   "Projects": {
#     "Challah": {
#       "PSCID": {
#         "Regex": "/^SITE{1,1}[0-9]{3,3}$/i",
#         "Type": "auto"
#       },
#       "useEDC": "false"
#     },
#     "DCP": {
#       "PSCID": {
#         "Regex": "/^SITE{1,1}[0-9]{3,3}$/i",
#         "Type": "auto"
#       },
#       "useEDC": "false"
#     },
#     "Oat": {
#       "PSCID": {
#         "Regex": "/^SITE{1,1}[0-9]{3,3}$/i",
#         "Type": "auto"
#       },
#       "useEDC": "false"
#     },
#     "Pumpernickel": {
#       "PSCID": {
#         "Regex": "/^SITE{1,1}[0-9]{3,3}$/i",
#         "Type": "auto"
#       },
#       "useEDC": "false"
#     },
#     "Rye": {
#       "PSCID": {
#         "Regex": "/^SITE{1,1}[0-9]{3,3}$/i",
#         "Type": "auto"
#       },
#       "useEDC": "false"
#     }
#   }
# }

# %% [markdown]
# ## Exercise 2.2 Get a specific project
#
# The endpoint `/projects/{project}` can be used to obtain information on a specific project contained the database.

# %%
# Find the project name and site name.
projects = json.loads(requests.get(
    url = baseurl + '/projects/rye',
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
).content.decode('ascii'))

prettyPrint(projects)
# Out:
# {
#   "Candidates": [
#     "103506",
#     "104483",
#     "133298",
#     "138588",
#     "154630",
#     "161569",
#     "178537",
#     "201245",
#     "207064",
#     "230757",
#     "245042",
#     "245807",
#     "294979",
#     "325968",
#     "330277",
#     "370350",
#     "378994",
#     "400162",
#     "400166",
#     "400171",
#     "400177",
#     "400178",
#     "400179",
#     "400180",
#     "400181",
#     "400183",
#     "400185",
#     "400186",
#     "400187",
#     "400190",
#     "400193",
#     "400196",
#     "400198",
#     "400205",
#     "400206",
#     "400207",
#     "400209",
#     "400210",
#     "400214",
#     "400218",
#     "400219",
#     "400221",
#     "400222",
#     "400228",
#     "400235",
#     "400240",
#     "400243",
#     "400246",
#     "400248",
#     "400249",
#     "400251",
#     "400254",
#     "400255",
#     "400258",
#     "400259",
#     "400260",
#     "400261",
#     "400263",
#     "400264",
#     "400268",
#     "400269",
# ...

# %% [markdown]
# ## Exercise 2.3 Get all the candidates in a specific project
#
# The endpoint `/projects/{project}/candidates` can be used to obtain information on all the candidates contained in a project.

# %%
# Find the project name and site name.
projects = json.loads(requests.get(
    url = baseurl + '/projects/rye/candidates',
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
).content.decode('ascii'))

prettyPrint(projects)
# Out:
# {
#   "Candidates": [
#     "103506",
#     "104483",
#     "133298",
#     "138588",
#     "154630",
#     "161569",
#     "178537",
#     "201245",
#     "207064",
#     "230757",
#     "245042",
#     "245807",
#     "294979",
#     "325968",
#     "330277",
#     "370350",
#     "378994",
#     "400162",
#     "400166",
#     "400171",
#     "400177",
#     "400178",
#     "400179",
#     "400180",
#     "400181",
#     "400183",
#     "400185",
#     "400186",
#     "400187",
#     "400190",
#     "400193",
#     "400196",
#     "400198",
#     "400205",
#     "400206",
#     "400207",
#     "400209",
#     "400210",
#     "400214",
#     "400218",
#     "400219",
#     "400221",
#     "400222",
#     "400228",
#     "400235",
#     "400240",
#     "400243",
#     "400246",
#     "400248",
#     "400249",
#     "400251",
#     "400254",
#     "400255",
#     "400258",
#     "400259",
#     "400260",
#     "400261",
#     "400263",
#     "400264",
#     "400268",
#     "400269",
# ...

# %% [markdown]
# ## Exercise 2.4 Get all the images in a specific project
#
# The endpoint `/projects/{project}/images` can be used to obtain information on all the images that are used in a project.

# %%
# Find the project name and site name.
projects = json.loads(requests.get(
    url = baseurl + '/projects/rye/images',
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
).content.decode('ascii'))

prettyPrint(projects)
# Out:
# {
#   "Images": [
#     {
#       "Candidate": "400162",
#       "InsertTime": "2019-05-23T18:26:27-04:00",
#       "Link": "/candidates/400162/V6/images/demo_400162_V6_t1_001.mnc",
#       "PSCID": "ROM162",
#       "QC_status": null,
#       "ScanType": "t1",
#       "Selected": "false",
#       "Site": "Rome",
#       "Visit": "V6",
#       "Visit_date": "2016-08-15"
#     },
#     {
#       "Candidate": "400162",
#       "InsertTime": "2019-05-23T18:26:30-04:00",
#       "Link": "/candidates/400162/V6/images/demo_400162_V6_t2_001.mnc",
#       "PSCID": "ROM162",
#       "QC_status": "Pass",
#       "ScanType": "t2",
#       "Selected": "true",
#       "Site": "Rome",
#       "Visit": "V6",
#       "Visit_date": "2016-08-15"
#     },
#     {
#       "Candidate": "400162",
#       "InsertTime": "2019-05-23T18:26:33-04:00",
#       "Link": "/candidates/400162/V6/images/demo_400162_V6_dwi25_001.mnc",
#       "PSCID": "ROM162",
#       "QC_status": null,
#       "ScanType": "dwi25",
# ...

# %% [markdown]
# ### Find recent images

# %%
# This gets all the images inserted since 2018-12-13T10:20:18-05:00
r = json.loads(requests.get(
    url = baseurl + '/projects/rye/images?since=2018-12-13T10:20:18-05:00' ,
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
).content.decode('ascii'))
prettyPrint(r)
# Out:
# {
#   "Images": [
#     {
#       "Candidate": "400162",
#       "InsertTime": "2019-05-23T18:26:27-04:00",
#       "Link": "/candidates/400162/V6/images/demo_400162_V6_t1_001.mnc",
#       "PSCID": "ROM162",
#       "QC_status": null,
#       "ScanType": "t1",
#       "Selected": "false",
#       "Site": "Rome",
#       "Visit": "V6",
#       "Visit_date": "2016-08-15"
#     },
#     {
#       "Candidate": "400162",
#       "InsertTime": "2019-05-23T18:26:30-04:00",
#       "Link": "/candidates/400162/V6/images/demo_400162_V6_t2_001.mnc",
#       "PSCID": "ROM162",
#       "QC_status": "Pass",
#       "ScanType": "t2",
#       "Selected": "true",
#       "Site": "Rome",
#       "Visit": "V6",
#       "Visit_date": "2016-08-15"
#     },
#     {
#       "Candidate": "400162",
#       "InsertTime": "2019-05-23T18:26:33-04:00",
#       "Link": "/candidates/400162/V6/images/demo_400162_V6_dwi25_001.mnc",
#       "PSCID": "ROM162",
#       "QC_status": null,
#       "ScanType": "dwi25",
# ...

# %% [markdown]
# ## Exercise 2.5 Get all the instruments in a specific project
#
# The endpoint `/projects/{project}/instruments` can be used to obtain information on all the instruments that are used in a project.

# %%
# Find the project name and site name.
projects = json.loads(requests.get(
    url = baseurl + '/projects/rye/instruments',
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
).content.decode('ascii'))

prettyPrint(projects)
# Out:
# {
#   "Instruments": {
#     "aosi": {
#       "DoubleDataEntryEnabled": true,
#       "Fullname": "AOSI",
#       "Subgroup": "Instruments"
#     },
#     "bmi": {
#       "DoubleDataEntryEnabled": true,
#       "Fullname": "BMI Calculator",
#       "Subgroup": "Instruments"
#     },
#     "medical_history": {
#       "DoubleDataEntryEnabled": true,
#       "Fullname": "Medical History",
#       "Subgroup": "Instruments"
#     },
#     "mri_parameter_form": {
#       "DoubleDataEntryEnabled": true,
#       "Fullname": "MRI Parameter Form",
#       "Subgroup": "Imaging"
#     },
#     "radiology_review": {
#       "DoubleDataEntryEnabled": true,
#       "Fullname": "Radiology review",
#       "Subgroup": "Instruments"
#     },
#     "test1": {
#       "DoubleDataEntryEnabled": true,
#       "Fullname": "test1",
#       "Subgroup": "Instruments"
#     },
#     "test23": {
#       "DoubleDataEntryEnabled": true,
#       "Fullname": "test23",
#       "Subgroup": "Instruments"
#     }
# ...

# %% [markdown]
# ## Exercise 2.6 Get a specific instruments in a specific project
#
# The endpoint `/projects/{project}/instruments/{instrument}` can be used to obtain information on a specific instrument that is used in a specific project.

# %%
# Find the project name and site name.
projects = json.loads(requests.get(
    url = baseurl + '/projects/rye/instruments/bmi',
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
).content.decode('ascii'))

prettyPrint(projects)
# Out:
# {
#   "Elements": [
#     {
#       "Description": "Date of Administration",
#       "Name": "Date_taken",
#       "Options": {
#         "MaxDate": "2012-12-31",
#         "MinDate": "2006-01-01"
#       },
#       "Type": "date"
#     },
#     {
#       "Description": "Examiner",
#       "Name": "Examiner",
#       "Options": {
#         "AllowMultiple": false,
#         "RequireResponse": false,
#         "Values": {
#           "": ""
#         }
#       },
#       "Type": "select"
#     },
#     {
#       "Description": "Choose unit of measurement",
#       "Name": "unit_classification",
#       "Options": {
#         "AllowMultiple": false,
#         "RequireResponse": false,
#         "Values": {
#           "": "",
#           "metric": "Metric",
#           "standard": "Standard"
#         }
#       },
#       "Type": "select"
#     },
#     {
#       "Description": "Your height (feet) :",
#       "Name": "height_feet",
#       "Options": {
#         "MaxValue": 0,
# ...

# %% [markdown]
# ## Exercise 2.7 Get a specific instruments in a specific project
#
# The endpoint `/projects/{project}/instruments/{instrument}` can be used to obtain information on a specific instrument that is used in a specific project.

# %%
# Find the project name and site name.
projects = json.loads(requests.get(
    url = baseurl + '/projects/rye/visits',
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
).content.decode('ascii'))

prettyPrint(projects)
# Out:
# {
#   "Meta": {
#     "Project": "Rye"
#   },
#   "Visits": [
#     "V1",
#     "V2",
#     "V3",
#     "V4",
#     "V5",
#     "V6"
#   ]
# }

# %% [markdown]
# # Exercice 3 - Candidates
#
# The endpoints in this section are used to get information on all candidates, to get information on a specific candidate or to add a new candidate.
#
# https://github.com/aces/Loris/blob/master/modules/api/docs/LorisRESTAPI_v0.0.3.md#30-candidate-api

# %% [markdown]
# ## Exercise 3.1 Get all candid
#
# The endpoint `/candidates` can be used to obtain information on all the candidates contained the database.

# %%
response = json.loads(requests.get(
    url = baseurl + '/candidates',
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
).content.decode('ascii'))
prettyPrint(response)
# Out:
# {
#   "Candidates": [
#     {
#       "CandID": "115788",
#       "DoB": "2020-01-01",
#       "EDC": "2001-01-01",
#       "PSCID": "DCC355",
#       "Project": "Pumpernickel",
#       "Sex": "Female",
#       "Site": "Data Coordinating Center"
#     },
#     {
#       "CandID": "161346",
#       "DoB": "2020-01-01",
#       "EDC": "2020-01-01",
#       "PSCID": "DCC731",
#       "Project": "Pumpernickel",
#       "Sex": "Female",
#       "Site": "Data Coordinating Center"
#     },
#     {
#       "CandID": "260901",
#       "DoB": "2020-01-01",
#       "EDC": "2020-01-01",
#       "PSCID": "DCC706",
#       "Project": "Pumpernickel",
#       "Sex": "Female",
#       "Site": "Data Coordinating Center"
#     },
#     {
#       "CandID": "267372",
#       "DoB": "2020-01-01",
#       "EDC": "2020-01-01",
#       "PSCID": "DCC707",
#       "Project": "Pumpernickel",
#       "Sex": "Female",
#       "Site": "Data Coordinating Center"
#     },
#     {
#       "CandID": "335458",
# ...

# %%
# Using a for loop, print the candids
candidates = response['Candidates']
for candidate in candidates:
    print(candidate['CandID'])
# Out:
# 115788
# 161346
# 260901
# 267372
# 335458
# 363428
# 368237
# 424284
# 475906
# 493895
# 511429
# 534302
# 584349
# 587630
# 676061
# 696846
# 719035
# 744745
# 749667
# 854760
# 938162
# 947103
# 983490
# 106148
# 205669
# 209916
# 268120
# 300001
# 300002
# 300003
# 300004
# 300005
# 300006
# 300007
# 300008
# 300009
# 300010
# 300011
# 300012
# 300013
# 300014
# 300015
# 300016
# 300017
# 300018
# 300019
# 300020
# 300021
# 300022
# 300023
# 300024
# 300025
# 300026
# 300027
# 300028
# 300029
# 300030
# 300031
# 300032
# 300033
# 300034
# 300035
# 300036
# 300037
# 300038
# 300039
# 300040
# 300041
# 300042
# 300043
# 300044
# 300045
# 300046
# 300047
# 300048
# 300049
# 300050
# 300051
# 300052
# 300053
# 300054
# 300055
# 300056
# 300057
# 300058
# 300059
# 300060
# 300061
# 300062
# 300063
# 300064
# 300065
# 300066
# 300067
# 300068
# 300069
# 300070
# 300071
# 300072
# 300073
# 300074
# 300075
# 300076
# 300077
# 300078
# 300079
# 300080
# 300081
# 300082
# 300083
# 300084
# ...

# %% [markdown]
# ## Exercise 3.2 Create a candidate
#  - Send a **POST** request to /candidates with a payload containing an object with a candidate property
#  ```json
#     "Candidate" : {
#         "Project" : ProjectName,
#         "PSCID"   : PSCID, # only if config is set to prompt
#         "EDC"     : "YYYY-MM-DD", # optional
#         "DoB"     : "YYYY-MM-DD",
#         "Gender"  : "Male|Female",
#         "Site"    : SiteName,
#     }
#  ```

# %%
projectname = projects['Meta']['Project']

sitename = 'Montreal'

json_data = {
    'Candidate' : {
        'Project' : projectname,
        'DoB'     : "2015-09-10",
        'EDC'     : "2015-09-10", #Optional
        'Sex'     : "Female",
        'Site'    : sitename,
    }
}

r = requests.post(
    url = baseurl + '/candidates/',
    json = json_data,
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
)
print(r)
print(r.headers)
json.loads(r.content.decode('ascii'))
# Out:
# <Response [201]>
# {'Server': 'nginx/1.16.1', 'Date': 'Mon, 20 Jul 2020 23:13:51 GMT', 'Content-Type': 'application/json', 'Content-Length': '123', 'Connection': 'keep-alive', 'Content-Security-Policy': "default-src 'self' 'unsafe-inline'; script-src 'self' 'unsafe-inline' 'unsafe-eval' ; font-src 'self' data:; img-src 'self' data:;", 'Set-Cookie': 'PHPSESSID=13592fr0h9dbscug02muv90cq7; path=/; HttpOnly; SameSite=1', 'Expires': 'Thu, 19 Nov 1981 08:52:00 GMT', 'Cache-Control': 'private, max-age=10800', 'Last-Modified': 'Thu, 18 Jun 2020 14:37:58 GMT', 'Content-Location': '/candidates/185341', 'ETag': '99914b932bd37a50b983c5e7c90ae93b'}
# {'CandID': '185341',
#  'Project': 'Rye',
#  'PSCID': 'MTL217',
#  'Site': 'Montreal',
#  'EDC': '2015-09-10',
#  'DoB': '2015-09-10',
#  'Sex': 'Female'}

# %% [markdown]
# ## Exercise 3.3 Get a specific candidate
#
# This is a GET request to /candidates/{candid}

# %%
# Get the new candidate
candid = '300001'

newcandidate = json.loads(requests.get(
    url = baseurl + '/candidates/' + candid,
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
).content.decode('ascii'))

prettyPrint(newcandidate)
# Out:
# {
#   "Meta": {
#     "CandID": "300001",
#     "DoB": "2003-10-31",
#     "EDC": "2003-11-30",
#     "PSCID": "MTL001",
#     "Project": "Pumpernickel",
#     "Sex": "Male",
#     "Site": "Montreal"
#   },
#   "Visits": [
#     "V1",
#     "V2",
#     "V3"
#   ]
# }

# %% [markdown]
# # Exercice 4 - Visits
#
# The endpoints in this section are used to get information on all candidates, to get information on a specific candidate or to add a new candidate.
#
# https://github.com/aces/Loris/blob/master/modules/api/docs/LorisRESTAPI_v0.0.3.md#40-imaging-data

# %% [markdown]
# ## Exercise 4.1 Get all visits for a specific candidate
#
# This is a GET request to /candidates/{candid}/{visit}

# %%
# Get the new candidate
visitlabel  = newcandidate['Visits'][0]

Visit = json.loads(requests.get(
    url = baseurl + '/candidates/' + candid + '/' + visitlabel,
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
).content.decode('ascii'))

prettyPrint(Visit)
# Out:
# {
#   "Meta": {
#     "Battery": "Fresh",
#     "CandID": "300001",
#     "Project": "Pumpernickel",
#     "Site": "Montreal",
#     "Visit": "V1"
#   },
#   "Stages": {
#     "Visit": {
#       "Date": "2018-03-26",
#       "Status": "In Progress"
#     }
#   }
# }

# %% [markdown]
# ## Exercise 4.2 Add a timepoint to the new candidate
#  - **PUT** request to /candidates/\$candid/\$visit_label
# ```json
# {
#     "Meta" : {
#         "Battery" : "Fresh",
#         "CandID" : CandID,
#         "Project" : "Pumpernickel",
#         "Visit"  : VisitLabel,
#         "Battery": "NameOfSubproject"
#     "Stages": {
#         "Visit": {
#             "Date": "2017-03-26",
#         }
#     }
# }
# ```
#
#  - All VisitLabels for a given candidates can be found using /candidates/\$candid/
#
#
#  - Every possible visit_labels for a project can be found using /projects/\$projectname/visits. If a \$visit_label is in /projects/\$projectname/visits but not in /candidates/\$candid/ , it can be added using a **PUT** request to /candidates/\$candid/\$visit_label
#
#
#  - Battery (NameOfSubproject) must be guessed...

# %%
json_data = {
        "Battery" : "Fresh",
        "Site" : "Montreal",
        "CandID" : candid,
        "Visit"  : visitlabel,
        "Project": "Pumpernickel"
}

r = requests.put(
    url = baseurl + '/candidates/' + str(candid) + '/' + visitlabel,
    json = json_data,
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
)

# The response will be <Response [201]> if the visit does not exist 
# for the selected candidate. 
# If the visit already exists, the response will be <Response [204]>

print(r)
print(r.content.decode('ascii'))
# Out:
# <Response [409]>
# {"error":"This visit is already started"}

# %% [markdown]
# ## Exercise 4.3 Get QC/imaging of a candidate visit
#
# This is a GET request to /candidates/{candid}/{visit}

# %%
# Endpoint BEFORE 
VisitqcImaging = json.loads(requests.get(
    url = baseurl + '/candidates/' + candid + 
    '/' + visitlabel + '/qc/imaging',
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
).content.decode('ascii'))

prettyPrint(VisitqcImaging)
# Out:
# {
#   "Meta": {
#     "CandID": "300001",
#     "Visit": "V1"
#   },
#   "Pending": true,
#   "SessionQC": ""
# }

# %% [markdown]
# ## Exercise 4.4 Change QC/imaging of a candidate visit
#  - **PUT** request to /candidates/\$candid/\$visit_label/qc/imaging
# ```json
# {
#     "Meta" : {
#         "CandID" : CandID,
#         "Visit"  : VisitLabel,
#         "Battery": "NameOfSubproject"
# }
# ```
#
#  - All VisitLabels for a given candidates can be found using /candidates/\$candid/
#
#
#  - Every possible visit_labels for a project can be found using /projects/\$projectname/visits. If a \$visit_label is in /projects/\$projectname/visits but not in /candidates/\$candid/ , it can be added using a **PUT** request to /candidates/\$candid/\$visit_label
#
#
#  - Battery (NameOfSubproject) must be guessed...

# %%
json_data = {
    'Meta' : {
        'CandID' : candid,
        'Visit'  : visitlabel,
    },
    'SessionQC': "",
    'Pending': True
}

r = requests.put(
    url = baseurl + '/candidates/' + str(candid) + '/' + visitlabel + '/qc/imaging',
    json = json_data,
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
)

VisitqcImaging = json.loads(requests.get(
    url = baseurl + '/candidates/' + candid +
    '/' + visitlabel + '/qc/imaging',
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
).content.decode('ascii'))

print(r)
prettyPrint(VisitqcImaging)

# The response will be <Response [201]> if the visit does not exist 
# for the selected candidate. 
# If the visit already exists, the response will be <Response [204]>
# Out:
# <Response [404]>
# {
#   "error": "Visit not found"
# }

# %% [markdown]
# # Exercice 5: Instrument data for a candidate

# %% [markdown]
# ## Exercise 5.1 GET all instruments for a candidate

# %%
instrument = 'aosi'
candid = '400162'
visit_label = 'V6'

# %%
def getInstrumentData(candid, visit_label):
    return json.loads(requests.get(
        url = baseurl + '/candidates/' + candid +
        '/' + visit_label + '/instruments/',
        verify = False,
        headers = {'Authorization': 'Bearer %s' % token}
    ).content.decode('ascii'))
    
prettyPrint(getInstrumentData(candid, visit_label))
# Out:
# {
#   "Instruments": [
#     "medical_history",
#     "mri_parameter_form",
#     "aosi"
#   ],
#   "Meta": {
#     "CandID": "400162",
#     "Visit": "V6"
#   }
# }

# %% [markdown]
# ## Exercise 5.2 Input instrument data for a candidate
#
# GET, PUT or PATCH request to /candidates/$CandID/$VisitLabel/instruments/$InstrumentName
#
# https://github.com/aces/Loris/blob/minor/docs/API/LorisRESTAPI.md#33-the-candidate-instrument-data
#
# data format:
# ```json
# {
#   "Meta": {
#     "Candidate": string,
#     "Visit": string
#     "DDE": true|false,
#     "Instrument": string,
#   },
#   <instrument_name>: {
#     <field1_name>: <value1>,
#     <field2_name>: <value2>,
#     ...
#   }
# }
# ```

# %% [markdown]
# ### 5.2.1 GET request containing all the fields

# %%
def getInstrumentData(candid, visit_label, instrument):
    return json.loads(requests.get(
        url = baseurl + '/candidates/' + candid +
        '/' + visit_label + '/instruments/' + instrument,
        verify = False,
        headers = {'Authorization': 'Bearer %s' % token}
    ).content.decode('ascii'))
    

prettyPrint(getInstrumentData(candid, visit_label, instrument))
# Out:
# {
#   "Meta": {
#     "Candidate": "400162",
#     "DDE": false,
#     "Instrument": "aosi",
#     "Visit": "V6"
#   },
#   "aosi": {
#     "Candidate_Age": "42",
#     "CommentID": "400162ROM162542361590159450",
#     "Data_entry_completion_status": "Incomplete",
#     "Date_taken": null,
#     "Examiner": null,
#     "Testdate": "2020-05-22 10:57:30",
#     "UserID": null,
#     "Window_Difference": null,
#     "examiner_location": null,
#     "free_play_period_1_notes": null,
#     "free_play_period_1_notes_status": null,
#     "free_play_period_2_notes": null,
#     "free_play_period_2_notes_status": null,
#     "number_of_markers": null,
#     "number_of_markers_override": null,
#     "other_comments": null,
#     "other_comments_status": null,
#     "q10_coordination_of_eye_gaze_and_action": null,
#     "q10_coordination_of_eye_gaze_and_action_notes": null,
#     "q10_coordination_of_eye_gaze_and_action_notes_status": null,
#     "q11_reactivity": null,
# ...

# %% [markdown]
# ### 5.2.2 PATCH request containing all the fields

# %%
# Get all the fields an meta data
json_input = getInstrumentData(candid, visit_label, instrument)

# Update one field
json_input[instrument]['Candidate_Age'] = 3
json_input[instrument]['UserID'] = 'something'

r = requests.patch(
    url = baseurl + '/candidates/' + candid + '/' + 
    visit_label + '/instruments/' + instrument,
    json = json_input,
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
)
print(r.status_code)

# Candidate_Age should be changed to '3' and UserID to 'something'
prettyPrint(getInstrumentData(candid, visit_label, instrument))
# Out:
# 204
# {
#   "Meta": {
#     "Candidate": "400162",
#     "DDE": false,
#     "Instrument": "aosi",
#     "Visit": "V6"
#   },
#   "aosi": {
#     "Candidate_Age": "3",
#     "CommentID": "400162ROM162542361590159450",
#     "Data_entry_completion_status": "Incomplete",
#     "Date_taken": null,
#     "Examiner": null,
#     "Testdate": "2020-05-22 10:57:30",
#     "UserID": "something",
#     "Window_Difference": null,
#     "examiner_location": null,
#     "free_play_period_1_notes": null,
#     "free_play_period_1_notes_status": null,
#     "free_play_period_2_notes": null,
#     "free_play_period_2_notes_status": null,
#     "number_of_markers": null,
#     "number_of_markers_override": null,
#     "other_comments": null,
#     "other_comments_status": null,
#     "q10_coordination_of_eye_gaze_and_action": null,
#     "q10_coordination_of_eye_gaze_and_action_notes": null,
#     "q10_coordination_of_eye_gaze_and_action_notes_status": null,
#     "q11_reactivity": null,
# ...

# %% [markdown]
# ### 5.2.3 PATCH request containing some of the fields

# %%
# Get all the fields an meta data
json_input = getInstrumentData(candid, visit_label, instrument)

# Update one field
json_input[instrument]['Candidate_Age'] = 41

r = requests.put(
    url = baseurl + '/candidates/' + candid + '/' + 
    visit_label + '/instruments/' + instrument,
    json = json_input,
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
)
print(r.status_code)

# Candidate_Age should be changed to '42' and UserID back to null
prettyPrint(getInstrumentData(candid, visit_label, instrument))

# PROBLEM: UserID stays at the current modified value
# Out:
# 204
# {
#   "Meta": {
#     "Candidate": "400162",
#     "DDE": false,
#     "Instrument": "aosi",
#     "Visit": "V6"
#   },
#   "aosi": {
#     "Candidate_Age": "41",
#     "CommentID": "400162ROM162542361590159450",
#     "Data_entry_completion_status": "Incomplete",
#     "Date_taken": null,
#     "Examiner": null,
#     "Testdate": "2020-05-22 10:57:30",
#     "UserID": "something",
#     "Window_Difference": null,
#     "examiner_location": null,
#     "free_play_period_1_notes": null,
#     "free_play_period_1_notes_status": null,
#     "free_play_period_2_notes": null,
#     "free_play_period_2_notes_status": null,
#     "number_of_markers": null,
#     "number_of_markers_override": null,
#     "other_comments": null,
#     "other_comments_status": null,
#     "q10_coordination_of_eye_gaze_and_action": null,
#     "q10_coordination_of_eye_gaze_and_action_notes": null,
#     "q10_coordination_of_eye_gaze_and_action_notes_status": null,
#     "q11_reactivity": null,
# ...

# %% [markdown]
# ## Exercise 5.3 Input instrument flags for a candidate
#
# PUT or PATCH request to /candidates/$CandID/$VisitLabel/instruments/$InstrumentName
#
# https://github.com/aces/Loris/blob/minor/docs/API/LorisRESTAPI.md#33-the-candidate-instrument-data
#
# data format:
# ```json
# {
#   "Meta": {
#     "Candidate": string,
#     "Visit": string
#     "DDE": false,
#     "Instrument": string,
#   },
#   "Flags": {
#     "Data_entry": string,
#     "Administration": string
#     "Validity": true|false
#   }
# }
# ```

# %% [markdown]
# ### 5.3.1 GET request containing all the fields

# %%
def getInstrumentFlags(candid, visit_label, instrument):
    return json.loads(requests.get(
        url = baseurl + '/candidates/' + candid + '/' 
        + visit_label + '/instruments/' + instrument
        + '/flags',
        verify = False,
        headers = {'Authorization': 'Bearer %s' % token}
    ).content.decode('ascii'))
    
r = getInstrumentFlags(candid, visit_label, instrument)
prettyPrint(r)
# Out:
# {
#   "Flags": {
#     "Administration": null,
#     "Data_entry": null,
#     "Validity": null
#   },
#   "Meta": {
#     "Candidate": "400162",
#     "DDE": false,
#     "Instrument": "aosi",
#     "Visit": "V6"
#   }
# }

# %% [markdown]
# #### 5.3.2 PUT request containing all the fields

# %%
json_input = getInstrumentFlags(candid, visit_label, instrument)

# Update one field
json_input['Flags']['Data_entry'] = '2'
r = requests.put(
    url = baseurl + '/candidates/' + candid + '/' + 
    visit_label + '/instruments/' + 'aosi' + '/flags',
    json = json_input,
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
 )

# not allowed
print(r.status_code)
# Data_entry should be changed to '2'
prettyPrint(getInstrumentFlags(candid, visit_label, instrument))
# Out:
# 405
# {
#   "Flags": {
#     "Administration": null,
#     "Data_entry": null,
#     "Validity": null
#   },
#   "Meta": {
#     "Candidate": "400162",
#     "DDE": false,
#     "Instrument": "aosi",
#     "Visit": "V6"
#   }
# }

# %% [markdown]
# #### 5.3.3 PATCH request containing some of the fields

# %%
# Get all the fields an meta data
json_input = getInstrumentFlags(candid, visit_label, instrument)

json_input['Flags']['Administation'] = '3'
r = requests.patch(
    url = baseurl + '/candidates/' + candid + '/'
    + visit_label + '/instruments/' + instrument 
    + '/flags',
    json = json_input,
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
)
# not allowed
print(r.status_code)

# Data_entry should be changed back to null and Administration changed to '3'
prettyPrint(getInstrumentFlags(candid, visit_label, instrument))
# Out:
# 405
# {
#   "Flags": {
#     "Administration": null,
#     "Data_entry": null,
#     "Validity": null
#   },
#   "Meta": {
#     "Candidate": "400162",
#     "DDE": false,
#     "Instrument": "aosi",
#     "Visit": "V6"
#   }
# }

# %% [markdown]
# ## Exercise 5.4 Input instrument DDE for a candidate
#
# GET, PUT or PATCH request to /candidates/$CandID/$VisitLabel/instruments/$InstrumentName
#
# https://github.com/aces/Loris/blob/minor/docs/API/LorisRESTAPI.md#33-the-candidate-instrument-data
#
# data format:
# ```json
# {
#   "Meta": {
#     "Candidate": string,
#     "DDE": true,
#     "Instrument": string,
#     "Visit": string
#   },
#   <instrument_name>: {
#     <field1_name>: <value1>,
#     <field2_name>: <value2>,
#     ...
#   }
# }
# ```

# %% [markdown]
# #### 5.4.1 GET request containing all the fields

# %%
def getInstrumentDde(candid, visit_label, instrument):
    return json.loads(requests.get(
        url = baseurl + '/candidates/' + candid + '/' 
        + visit_label + '/instruments/' + instrument
        + '/dde',
        verify = False,
        headers = {'Authorization': 'Bearer %s' % token}
    ).content.decode('ascii'))
    

prettyPrint(getInstrumentDde(candid, visit_label, instrument))
# Out:
# {
#   "Meta": {
#     "Candidate": "400162",
#     "DDE": true,
#     "Instrument": "aosi",
#     "Visit": "V6"
#   },
#   "aosi": {
#     "Candidate_Age": null,
#     "CommentID": "DDE_400162ROM162542361590159450",
#     "Data_entry_completion_status": "Incomplete",
#     "Date_taken": null,
#     "Examiner": null,
#     "Testdate": "2020-05-22 10:57:30",
#     "UserID": null,
#     "Window_Difference": null,
#     "examiner_location": null,
#     "free_play_period_1_notes": null,
#     "free_play_period_1_notes_status": null,
#     "free_play_period_2_notes": null,
#     "free_play_period_2_notes_status": null,
#     "number_of_markers": null,
#     "number_of_markers_override": null,
#     "other_comments": null,
#     "other_comments_status": null,
#     "q10_coordination_of_eye_gaze_and_action": null,
#     "q10_coordination_of_eye_gaze_and_action_notes": null,
#     "q10_coordination_of_eye_gaze_and_action_notes_status": null,
#     "q11_reactivity": null,
# ...

# %% [markdown]
# #### 5.4.2 PATCH request containing all the fields

# %%
# Get all the fields an meta data
json_input = getInstrumentDde(candid, visit_label, instrument)

# Update one field
json_input[instrument]['Candidate_Age'] = 5
json_input[instrument]['UserID'] = '30'

r = requests.patch(
    url = baseurl + '/candidates/' + candid + '/'
    + visit_label + '/instruments/' + instrument 
    + '/dde',
    json = json_input,
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
)
print(r.status_code)

# Candidate_Age should be changed to '5' and UserID be 30
prettyPrint(getInstrumentDde(candid, visit_label, instrument))
# Out:
# 204
# {
#   "Meta": {
#     "Candidate": "400162",
#     "DDE": true,
#     "Instrument": "aosi",
#     "Visit": "V6"
#   },
#   "aosi": {
#     "Candidate_Age": "5",
#     "CommentID": "DDE_400162ROM162542361590159450",
#     "Data_entry_completion_status": "Incomplete",
#     "Date_taken": null,
#     "Examiner": null,
#     "Testdate": "2020-05-22 10:57:30",
#     "UserID": "30",
#     "Window_Difference": null,
#     "examiner_location": null,
#     "free_play_period_1_notes": null,
#     "free_play_period_1_notes_status": null,
#     "free_play_period_2_notes": null,
#     "free_play_period_2_notes_status": null,
#     "number_of_markers": null,
#     "number_of_markers_override": null,
#     "other_comments": null,
#     "other_comments_status": null,
#     "q10_coordination_of_eye_gaze_and_action": null,
#     "q10_coordination_of_eye_gaze_and_action_notes": null,
#     "q10_coordination_of_eye_gaze_and_action_notes_status": null,
#     "q11_reactivity": null,
# ...

# %% [markdown]
# #### 5.4.2 PUT request containing all the fields

# %%
# Get all the fields an meta data
json_input = getInstrumentDde(candid, visit_label, instrument)

# Update another field
json_input[instrument]['UserID'] = '3'

r = requests.put(
    url = baseurl + '/candidates/' + candid + '/'
    + visit_label + '/instruments/' + instrument 
    + '/dde',
    json = json_input,
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
)
print(r.status_code)


# UserID should be changed to '3' and UserID to the default null
prettyPrint(getInstrumentDde(candid, visit_label, instrument))
# Out:
# 204
# {
#   "Meta": {
#     "Candidate": "400162",
#     "DDE": true,
#     "Instrument": "aosi",
#     "Visit": "V6"
#   },
#   "aosi": {
#     "Candidate_Age": "5",
#     "CommentID": "DDE_400162ROM162542361590159450",
#     "Data_entry_completion_status": "Incomplete",
#     "Date_taken": null,
#     "Examiner": null,
#     "Testdate": "2020-05-22 10:57:30",
#     "UserID": "3",
#     "Window_Difference": null,
#     "examiner_location": null,
#     "free_play_period_1_notes": null,
#     "free_play_period_1_notes_status": null,
#     "free_play_period_2_notes": null,
#     "free_play_period_2_notes_status": null,
#     "number_of_markers": null,
#     "number_of_markers_override": null,
#     "other_comments": null,
#     "other_comments_status": null,
#     "q10_coordination_of_eye_gaze_and_action": null,
#     "q10_coordination_of_eye_gaze_and_action_notes": null,
#     "q10_coordination_of_eye_gaze_and_action_notes_status": null,
#     "q11_reactivity": null,
# ...

# %% [markdown]
# ## Exercise 5.5 Input instrument DDE flags for a candidate
#
# PUT or PATCH request to /candidates/$CandID/$VisitLabel/instruments/$InstrumentName
#
# https://github.com/aces/Loris/blob/minor/docs/API/LorisRESTAPI.md#33-the-candidate-instrument-data
#
# data format:
# ```json
# {
#   "Meta": {
#     "Candidate": string,
#     "Visit": string
#     "DDE": true,
#     "Instrument": string,
#   },
#   "Flags": {
#     "Data_entry": string,
#     "Administration": string
#     "Validity": true|false
#   }
# }
# ```

# %% [markdown]
# ### 5.5.1 GET request containing all the fields

# %%
def getInstrumentDdeFlags(candid, visit_label, instrument):
    return json.loads(requests.get(
        url = baseurl + '/candidates/' + candid + '/' 
        + visit_label + '/instruments/' + instrument
        + '/dde/flags',
        verify = False,
        headers = {'Authorization': 'Bearer %s' % token}
    ).content.decode('ascii'))
    
prettyPrint(getInstrumentDde(candid, visit_label, instrument))
# Out:
# {
#   "Meta": {
#     "Candidate": "400162",
#     "DDE": true,
#     "Instrument": "aosi",
#     "Visit": "V6"
#   },
#   "aosi": {
#     "Candidate_Age": "5",
#     "CommentID": "DDE_400162ROM162542361590159450",
#     "Data_entry_completion_status": "Incomplete",
#     "Date_taken": null,
#     "Examiner": null,
#     "Testdate": "2020-05-22 10:57:30",
#     "UserID": "3",
#     "Window_Difference": null,
#     "examiner_location": null,
#     "free_play_period_1_notes": null,
#     "free_play_period_1_notes_status": null,
#     "free_play_period_2_notes": null,
#     "free_play_period_2_notes_status": null,
#     "number_of_markers": null,
#     "number_of_markers_override": null,
#     "other_comments": null,
#     "other_comments_status": null,
#     "q10_coordination_of_eye_gaze_and_action": null,
#     "q10_coordination_of_eye_gaze_and_action_notes": null,
#     "q10_coordination_of_eye_gaze_and_action_notes_status": null,
#     "q11_reactivity": null,
# ...

# %%
getInstrumentDdeFlags(candid, visit_label, instrument)
# Out:
# {'Meta': {'Candidate': '300004',
#   'Visit': 'V1',
#   'DDE': True,
#   'Instrument': 'aosi'},
#  'Flags': {'Data_entry': None, 'Administration': None, 'Validity': None}}

# %% [markdown]
# ### 5.5.2 PATCH request

# %%
# Get all the fields an meta data
json_input = getInstrumentDdeFlags(candid, visit_label, instrument)

# Update one field
json_input['Flags']['Data_entry'] = 3

r = requests.patch(
    url = baseurl + '/candidates/' + candid + '/'
    + visit_label + '/instruments/' + instrument 
    + '/dde/flags',
    json = json_input,
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
)
print(r.status_code)

# prettyPrint(getInstrumentDdeFlags(candid, visit_label, instrument))
# Out:
# 405

# %% [markdown]
# ### 5.5.3 PUT request

# %%
# Get all the fields an meta data
json_input = getInstrumentDdeFlags(candid, visit_label, instrument)

# Update another field
json_input["Flags"]['UserID'] = 301

r = requests.put(
    url = baseurl + '/candidates/' + candid + '/'
    + visit_label + '/instruments/' + instrument 
    + '/dde/flags',
    json = json_input,
    verify = False,
    headers = {'Authorization': 'Bearer %s' % token}
)
print(r.status_code)

# prettyPrint(getInstrumentDdeFlags(candid, visit_label, instrument))
# Out:
# 405

# %% [markdown]
# ## Exercise 5.6. Find all candidates and session with a given instruments
#
# This is a series of GET request
#
# https://github.com/aces/Loris/blob/minor/docs/API/LorisRESTAPI.md#31-specific-candidate
# https://github.com/aces/Loris/blob/minor/docs/API/LorisRESTAPI.md#33-candidate-instruments
# https://github.com/aces/Loris/blob/minor/docs/API/LorisRESTAPI.md#33-the-candidate-instrument-data

# %%
instrument = 'aosi'
request_count = 0

for candidate in candidates:
    candid = candidate['CandID']
    response = json.loads(requests.get(
        url = baseurl + '/candidates/' + candid,
        verify = False,
        headers = {'Authorization': 'Bearer %s' % token}
    ).content.decode('ascii'))
    request_count += 1
    visit_labels = response['Visits']
    for visit_label in visit_labels:
        response = json.loads(requests.get(
            url = baseurl + '/candidates/' + candid + '/' + visit_label + '/instruments',
            verify = False,
            headers = {'Authorization': 'Bearer %s' % token}
        ).content.decode('ascii'))
        request_count += 1
        if instrument in response['Instruments']:
            response = json.loads(requests.get(
                url = baseurl + '/candidates/' + candid + '/' + visit_label + '/instruments/' + instrument,
                verify = False,
                headers = {'Authorization': 'Bearer %s' % token}
            ).content.decode('ascii'))
            request_count += 1
            print(json.dumps(response, indent=2, sort_keys=True))
# Out:
# {
#   "Meta": {
#     "Candidate": "475906",
#     "DDE": false,
#     "Instrument": "aosi",
#     "Visit": "V1"
#   },
#   "aosi": {
#     "Candidate_Age": null,
#     "CommentID": "475906DCC4222142161524502652",
#     "Data_entry_completion_status": "Incomplete",
#     "Date_taken": null,
#     "Examiner": null,
#     "Testdate": "2018-04-23 16:57:32",
#     "UserID": null,
#     "Window_Difference": null,
#     "examiner_location": null,
#     "free_play_period_1_notes": null,
#     "free_play_period_1_notes_status": null,
#     "free_play_period_2_notes": null,
#     "free_play_period_2_notes_status": null,
#     "number_of_markers": null,
#     "number_of_markers_override": null,
#     "other_comments": null,
#     "other_comments_status": null,
#     "q10_coordination_of_eye_gaze_and_action": null,
#     "q10_coordination_of_eye_gaze_and_action_notes": null,
#     "q10_coordination_of_eye_gaze_and_action_notes_status": null,
#     "q11_reactivity": null,
# ...

# %%
print(request_count)
# Out:
# 2530

# %% [markdown]
# # Exercice 6: Images data for a candidate

# %%
candid_img = '400162'
visit_img = 'V6'
imagename = 'demo_400162_V6_t1_001.mnc'

# %% [markdown]
# ## Exercise 6.1 Find all images of a candidate for a visit

# %%
def getCandidateImages(candid, visit_label, imagename):
    return json.loads(requests.get(
        url = baseurl + '/candidates/' + candid_img + '/' 
        + visit_img + '/images/',
        verify = False,
        headers = {'Authorization': 'Bearer %s' % token}
    ).content.decode('ascii'))
r = getCandidateImages(candid_img, visit_img, imagename)

prettyPrint(r)
# Out:
# {
#   "Files": [
#     {
#       "AcquisitionType": "t1",
#       "Filename": "demo_400162_V6_t1_001.mnc",
#       "OutputType": "native"
#     },
#     {
#       "AcquisitionType": "t2",
#       "Filename": "demo_400162_V6_t2_001.mnc",
#       "OutputType": "native"
#     },
#     {
#       "AcquisitionType": "dwi25",
#       "Filename": "demo_400162_V6_dwi25_001.mnc",
#       "OutputType": "native"
#     }
#   ],
#   "Meta": {
#     "CandID": "400162",
#     "Visit": "V6"
#   }
# }

# %% [markdown]
# ## Exercise 6.2 Download minc files

# %%
for file in r['Files']:
    filename = file['Filename']
    image = requests.get(
        url = baseurl + '/candidates/' + candid_img
        + '/' + visit_img + '/images/' + filename,
        verify = False,
        headers = {'Authorization': 'Bearer %s' % token}
    )
    mincfile = open(filename, "w+b")
    mincfile.write(bytes(image.content))

# %% [markdown]
# ## Exercise 6.3 GET QC data for a MINC image file

# %%
# Get all images from that candidate
def getCandidateImageQc(candid, visit, imagename):
    return json.loads(requests.get(
        url = baseurl + '/candidates/' + candid + '/'
        + visit + '/images/' + imagename + '/qc',
        verify = False,
        headers = {'Authorization': 'Bearer %s' % token}
    ).content.decode('ascii'))
    
getCandidateImageQc(candid_img, visit_img, imagename)
# Out:
# {'Meta': {'CandID': '400162',
#   'Visit': 'V6',
#   'File': 'demo_400162_V6_t1_001.mnc'},
#  'QC': None,
#  'Selected': True,
#  'Caveats': [{'Severity': None,
#    'Header': None,
#    'Value': None,
#    'ValidRange': None,
#    'ValidRegex': None}]}

# %% [markdown]
# ## Exercise 6.4 PUT QC data for a MINC image file
#
# PUT request to /candidates/$CandID/$VisitLabel/images/$imagename/qc
#
# https://github.com/aces/Loris/blob/minor/docs/API/LorisRESTAPI.md#
#
# data format:
# ```json
# {
#             'Meta'     : {
#                 'CandID' : string,
#                 'Visit'  : string,
#                 'File'   : string
#             },
#             "QC"       : string|null,
#             "Selected" : boolean,
#             'Caveats'  : {
#                 '0' : {
#                     'Severity'   : string|null,
#                     'Header'     : string|null,
#                     'Value'      : string|null,
#                     'ValidRange' : string|null,
#                     'ValidRegex' : string|null
#                     }
#                 }
# }```

# %%
json_input = getCandidateImageQc(candid_img, visit_img, imagename)
json_input['Selected'] = False
r = requests.put(
    url = baseurl + '/candidates/' + candid_img + '/'
    + visit_img + '/images/' + imagename + '/qc',
    verify = False,
    json = json_input,
    headers = {'Authorization': 'Bearer %s' % token}
)
print(r.status_code)

# THIS PUT REQUEST HAS NO EFFECT
getCandidateImageQc(candid_img, visit_img, imagename)
# Out:
# 204
# {'Meta': {'CandID': '400162',
#   'Visit': 'V6',
#   'File': 'demo_400162_V6_t1_001.mnc'},
#  'QC': None,
#  'Selected': True,
#  'Caveats': [{'Severity': None,
#    'Header': None,
#    'Value': None,
#    'ValidRange': None,
#    'ValidRegex': None}]}

# %% [markdown]
# ## Exercise 6.5 GET Image formats

# %% [markdown]
# ### Exercise 6.5.1 GET Image Brainbrowser format

# %%
# Get all images from that candidate
def getCandidateImageFormatBrainbrowser(candid, visit, imagename):
    return json.loads(requests.get(
        url = baseurl + '/candidates/' + candid + '/'
        + visit + '/images/' + imagename + '/format/brainbrowser',
        verify = False,
        headers = {'Authorization': 'Bearer %s' % token}
    ).content.decode('ascii'))
    
getCandidateImageFormatBrainbrowser(candid_img, visit_img, imagename)
# Out:
# {'order': 'xspace,zspace,yspace',
#  'xspace': {'space_length': '160',
#   'start': '83.2540277529565',
#   'step': '-0.999999999999999'},
#  'yspace': {'space_length': '224', 'start': '128.631468978825', 'step': '-1.'},
#  'zspace': {'space_length': '256', 'start': '123.251700888517', 'step': '-1.'}}

# %% [markdown]
# ### Exercise 6.5.2 GET Image Raw format

# %%
# Get all images from that candidate
def getCandidateImageFormatRaw(candid, visit, imagename):
    return requests.get(
        url = baseurl + '/candidates/' + candid + '/'
        + visit + '/images/' + imagename + '/format/raw',
        verify = False,
        headers = {'Authorization': 'Bearer %s' % token}
    )
    
raw = getCandidateImageFormatRaw(candid_img, visit_img, imagename)
thumbnail = open('raw', "w+b")
thumbnail.write(bytes(raw.content))
# Out:
# 9175040

# %% [markdown]
# ### Exercise 6.5.3 GET Image Thumbnail format

# %%
# Get all images from that candidate
def getCandidateImageThumbnail(candid, visit, imagename):
    return requests.get(
        url = baseurl + '/candidates/' + candid + '/'
        + visit + '/images/' + imagename + '/format/thumbnail',
        verify = False,
        headers = {'Authorization': 'Bearer %s' % token}
    )
    
img = getCandidateImageThumbnail(candid_img, visit_img, imagename)
thumbnail = open('thumbnail', "w+b")
thumbnail.write(bytes(img.content))
# Out:
# 36702

# %% [markdown]
# ## Exercise 6.6 GET Image headers

# %% [markdown]
# ### Exercise 6.6.1 GET Image headers

# %%
# Get all images from that candidate
def getCandidateImageHeaders(candid, visit, imagename):
    return json.loads(requests.get(
        url = baseurl + '/candidates/' + candid + '/'
        + visit + '/images/' + imagename + '/headers',
        verify = False,
        headers = {'Authorization': 'Bearer %s' % token}
    ).content.decode('ascii'))
    
getCandidateImageHeaders(candid_img, visit_img, imagename)
# Out:
# {'Meta': {'CandID': '400162',
#   'Visit': 'V6',
#   'File': 'demo_400162_V6_t1_001.mnc'},
#  'Physical': {'TE': '0.00316',
#   'TR': '2.4',
#   'TI': '1.2',
#   'SliceThickness': '1.'},
#  'Description': {'SeriesName': 't1_mpr_1mm_p2_pos50',
#   'SeriesDescription': 't1_mpr_1mm_p2_pos50'},
#  'Dimensions': {'XSpace': {'Length': '160', 'StepSize': '-0.999999999999999'},
#   'YSpace': {'Length': '224', 'StepSize': '-1.'},
#   'ZSpace': {'Length': '256', 'StepSize': '-1.'}},
#  'ScannerInfo': {'Manufacturer': 'SIEMENS',
#   'Model': 'TrioTim',
#   'SoftwareVersion': 'syngo MR B17',
#   'SerialNumber': '35412',
#   'FieldStrength': '3.'}}

# %% [markdown]
# ### Exercise 6.6.2 GET Image headers full

# %%
# Get all images from that candidate
def getCandidateImageQc(candid, visit, imagename):
    return requests.get(
        url = baseurl + '/candidates/' + candid + '/'
        + visit + '/images/' + imagename + '/headers/full',
        verify = False,
        headers = {'Authorization': 'Bearer %s' % token}
    )

# %% [markdown]
# ### Exercise 6.6.3 GET Image headers headername

# %%
# Get all images from that candidate
def getCandidateImageQc(candid, visit, imagename):
    return json.loads(requests.get(
        url = baseurl + '/candidates/' + candid + '/'
        + visit + '/images/' + imagename + '/headers/full',
        verify = False,
        headers = {'Authorization': 'Bearer %s' % token}
    ).content.decode('ascii'))
    
getCandidateImageQc(candid_img, visit_img, imagename)
# Out:
# {'Meta': {'CandID': '400162',
#   'Visit': 'V6',
#   'File': 'demo_400162_V6_t1_001.mnc'},
#  'Headers': {'slice_thickness': '1',
#   'acquisition:slice_order': 'ascending',
#   'dicom_0x0051:el_0x1011': 'p2',
#   'image:vartype': 'group________',
#   'acquisition:percent_sampling': '100.',
#   'dicom_0x0051:el_0x1012': 'TP 0',
#   'dicom_0x0028:vartype': 'group________',
#   'yspace:alignment': 'centre',
#   'acquisition:receive_coil': 'HeadMatrixix\\"\\"',
#   'max:vartype': 'var_attribute',
#   'acquisition:num_slices': '1.',
#   'pixel_bandwidth': '219',
#   'dicom_0x0019:el_0x1015': '-87.56604066, -128.00403218, 120.89427608',
#   'xspace': '160',
#   'xstep': '-0.999999999999999',
#   'acquisition_matrix': '0s, 256s, 224s, 0s',
#   'dicom_0x0019:varid': 'MNI DICOM variable',
#   'acquisition:injection_route': '\\b',
#   'acquisition:tracer': '%%%%%%%%',
#   'study_id': '1',
#   'xspace:version': 'MINC Version    1.0',
#   'dicom_0x0051:vartype': 'group________',
# ...

# %% [markdown]
# # Exercise 7 - Dicoms

# %%
dicom_name = 'DCM_2016-08-15_ImagingUpload-18-25-i9GRv3.tar'
dicom_visit = 'V6'
dicom_candid = '400162'

# %% [markdown]
# ## Exercise 7.1 GET Image headers

# %%
# Get all images from that candidate
def getCandidateDicoms(candid, visit):
    return json.loads(requests.get(
        url = baseurl + '/candidates/' + candid + '/'
        + visit + '/dicoms/',
        verify = False,
        headers = {'Authorization': 'Bearer %s' % token}
    ).content.decode('ascii'))
    
getCandidateDicoms(dicom_candid, dicom_visit)
# Out:
# {'Meta': {'CandID': '400162', 'Visit': 'V6'},
#  'DicomTars': [{'Tarname': 'DCM_2016-08-15_ImagingUpload-18-25-i9GRv3.tar',
#    'SeriesInfo': [{'SeriesDescription': 'localizer',
#      'SeriesNumber': 1,
#      'EchoTime': '5',
#      'RepetitionTime': '20',
#      'InversionTime': None,
#      'SliceThickness': '10',
#      'Modality': 'MR',
#      'SeriesUID': '1.3.12.2.1107.5.2.32.35412.201001121301452103600531.0.0.0'},
#     {'SeriesDescription': 't1_mpr_1mm_p2_pos50',
#      'SeriesNumber': 2,
#      'EchoTime': '3.16',
#      'RepetitionTime': '2400',
#      'InversionTime': '1200',
#      'SliceThickness': '1',
#      'Modality': 'MR',
#      'SeriesUID': '1.3.12.2.1107.5.2.32.35412.2010011213031389145301337.0.0.0'},
#     {'SeriesDescription': 't2_spc_1mm_p2',
#      'SeriesNumber': 3,
#      'EchoTime': '497',
#      'RepetitionTime': '3200',
#      'InversionTime': None,
#      'SliceThickness': '1',
#      'Modality': 'MR',
# ...

# %% [markdown]
# ## Exercise 7.2 GET Image headers

# %%
# Get all images from that candidate
def getCandidateDicomsTarchive(candid, visit, dicom_name):
    return requests.get(
        url = baseurl + '/candidates/' + candid + '/'
        + visit + '/dicoms/' + dicom_name,
        verify = False,
        headers = {'Authorization': 'Bearer %s' % token}
    )
tar = getCandidateDicomsTarchive(dicom_candid, dicom_visit, dicom_name)
dicom = open(dicom_name, "w+b")
dicom.write(bytes(tar.content))
# Out:
# 44175360

# %% [markdown]
# # Visualisation of a Minc file
#
# Using nibabel

# %%
import requests
import nibabel as nib
r = requests.get(baseurl + 
                 '/candidates/587630/V1/images/demo_587630_V1_t1_001.mnc', 
                 headers = {'Authorization': 'Bearer %s' % token})
page = r.content
# Write data to file
filename = "demo_587630_V1_t1_001.mnc"
file_ = open(filename, 'wb')
file_.write(page)
file_.close()
img = nib.load(filename)
data = img.get_fdata()
data.shape
# Out:
# (160, 256, 224)

# %%
import ipyvolume as ipv
from matplotlib.pyplot import cm
import numpy as np
table_ct = cm.gray_r(np.linspace(0, 1, 255))
table_ct[:50, 3] = 0 # make the lower values transparent
table_ct[50:, 3] = np.linspace(0, 0.05, table_ct[50:].shape[0])
tf_ct = ipv.TransferFunction(rgba=table_ct)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-243-26362d285025> in <module>
# ----> 1 import ipyvolume as ipv
#       2 from matplotlib.pyplot import cm
#       3 import numpy as np
#       4 table_ct = cm.gray_r(np.linspace(0, 1, 255))
#       5 table_ct[:50, 3] = 0 # make the lower values transparent
#
# ModuleNotFoundError: No module named 'ipyvolume'

# %%
ipv.quickvolshow(np.array(img.dataobj))

# %%
import nilearn.plotting as nlplt

# %%
view = nlplt.view_img(filename)
view
# view.open_in_browser()

# %%
view = nlplt.plot_glass_brain(img)
view

# %%
view = nlplt.plot_anat(filename)
view
